# %% [markdown]
# # **정사각형으로 만들기**

# %% [markdown]
# **이차원 정수 배열 arr이 매개변수로 주어집니다. arr의 행의 수가 더 많다면 열의 수가 행의 수와 같아지도록 각 행의 끝에 0을 추가하고, 열의 수가 더 많다면 행의 수가 열의 수와 같아지도록 각 열의 끝에 0을 추가한 이차원 배열을 return 하는 solution 함수를 작성해 주세요.**

# %%
def solution(arr):
    answer = []
    temp = len(arr)
    temp_1 = len(arr[0])
    
    if temp > temp_1:
        for i in arr:
            answer.append(i+([0]*(temp - temp_1)))
    elif temp == temp_1:
        answer = arr
    else:
        answer = arr
        for i in range(0,(temp_1 - temp)):
            answer.append([0]*temp_1)

    return answer
